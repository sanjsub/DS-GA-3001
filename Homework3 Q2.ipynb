# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('soccer18m.csv')
data = data[data.Y < 18]
data['GameID'] = data.index
data['HomeWin'] = 1*(data['FTHG'] > data['FTAG'])
data.head()
# Out:
#    Div        Date   Y    HomeTeam        AwayTeam  FTHG  FTAG  HTHG  HTAG  \
# 0  EPL  2014-08-16  14     Arsenal  Crystal Palace     2     1     1     1
# 1  EPL  2014-08-16  14   Leicester         Everton     2     2     1     2
# 2  EPL  2014-08-16  14  Man United         Swansea     1     2     0     1
# 3  EPL  2014-08-16  14         QPR            Hull     0     1     0     0
# 4  EPL  2014-08-16  14       Stoke     Aston Villa     0     1     0     0
#
#    HS  AS  HST  AST        pH        pD        pA   home_xG   away_xG  GameID  \
# 0  14   4    6    2  0.778038  0.151989  0.069973  1.554110  0.158151       0
# 1  11  13    3    3  0.311972  0.289820  0.398208  1.278300  0.613273       1
# 2  14   5    5    4  0.715373  0.192169  0.092459  1.166350  0.278076       2
# 3  19  11    6    4  0.395113  0.300577  0.304311  1.900670  1.117570       3
# 4  12   7    2    2  0.502378  0.282316  0.215305  0.423368  0.909774       4
#
#    HomeWin
# 0        1
# 1        0
# ...

# %%
data['upset'] = np.where((data.pH < data.pA) & (data.HomeWin == 1),1, np.where((data.pA < data.pH) & (data.HomeWin == 0),1,0))
dataupset = data[data.upset == 1]

#dataupset['win_prob'] = np.where(data.HomeWin == 1, data.pH, data.pA)
#data1 = dataupset.nsmallest(7,'pH')
#data2 = dataupset.nsmallest(7,'pA')
upset = dataupset.nsmallest(7,'win_prob')

# %%
dataupset
# Out:
#           Div        Date   Y     HomeTeam     AwayTeam  FTHG  FTAG  HTHG  \
# 2         EPL  2014-08-16  14   Man United      Swansea     1     2     0
# 3         EPL  2014-08-16  14          QPR         Hull     0     1     0
# 4         EPL  2014-08-16  14        Stoke  Aston Villa     0     1     0
# 5         EPL  2014-08-16  14    West Brom   Sunderland     2     2     1
# 10        EPL  2014-08-23  14  Aston Villa    Newcastle     0     0     0
# ...       ...         ...  ..          ...          ...   ...   ...   ...
# 9104  La_Liga  2018-05-19  17      Leganes        Betis     3     2     1
# 9112  Ligue_1  2018-01-28  17     Bordeaux         Lyon     3     1     3
# 9116  Ligue_1  2018-04-20  17       Nantes       Rennes     1     1     1
# 9120  Ligue_1  2018-04-27  17  Montpellier   St Etienne     0     1     0
# 9122  Ligue_1  2018-04-29  17     Paris SG     Guingamp     2     2     0
#
#       HTAG  HS  ...  HST  AST        pH        pD        pA   home_xG  \
# ...
